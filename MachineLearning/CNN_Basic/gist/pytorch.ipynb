# %%
import torch

# %%
a = torch.randn((27, 27))
b = torch.randn((27, 27))
c = a @ b
print(c)
# Out:
# tensor([[-2.8842e-01,  8.8743e-01,  2.6646e+00, -1.0690e+00, -5.3135e+00,
#          -2.9488e+00,  7.9972e+00,  3.3499e+00,  3.7210e+00, -2.6119e+00,
#          -4.2035e+00, -5.5450e+00,  1.3360e+00,  5.0036e+00, -9.8313e+00,
#           4.4368e+00,  3.7821e+00,  9.2340e+00, -8.3931e+00, -5.8912e+00,
#          -1.0941e+00, -1.7375e+00,  7.6821e+00, -3.5348e+00, -1.5088e+00,
#          -1.4322e+00, -3.3414e+00],
#         [-5.0902e+00, -1.1032e+01, -2.9506e+00, -2.6267e+00,  6.2009e-01,
#          -2.8678e+00, -2.4011e+00,  5.8607e+00, -1.8650e+00, -2.5548e+00,
#           5.1979e+00,  3.7982e+00,  5.6542e+00, -8.7112e-01,  1.8406e+00,
#           2.2867e+00, -3.8661e-01,  3.2327e+00, -1.5426e+00, -1.1224e+01,
#           9.2195e+00, -5.7807e+00, -8.4951e+00,  1.3825e+00,  1.8863e+00,
#          -2.2157e+00, -4.6825e+00],
#         [-3.9398e+00, -5.3278e+00, -2.3981e+00,  6.2938e+00, -2.4429e+00,
#           1.0512e+01, -7.6212e-02, -6.7278e-02,  4.8356e+00,  7.7575e+00,
# ...

# %%
a = torch.randn(50, 30)
print(a.shape)
print(a[1,:])
b = a.t()
print(b.shape)
print(b[:,1])
print(b[:,1])
c = a@b
print(c.shape)
# Out:
# torch.Size([50, 30])
# tensor([-0.1957,  0.3659, -1.8744, -1.4473,  1.0419, -0.7933, -0.3247,  0.1608,
#          1.4083,  2.0132,  0.2615,  1.1895, -0.7192, -0.8945, -0.1287,  0.6286,
#         -0.1858,  0.0897,  0.3478, -0.6387, -0.8527,  0.6187, -1.2488,  0.3053,
#          1.4715,  0.2047,  0.3558,  0.2409,  0.8499,  0.2798])
# torch.Size([30, 50])
# tensor([-0.1957,  0.3659, -1.8744, -1.4473,  1.0419, -0.7933, -0.3247,  0.1608,
#          1.4083,  2.0132,  0.2615,  1.1895, -0.7192, -0.8945, -0.1287,  0.6286,
#         -0.1858,  0.0897,  0.3478, -0.6387, -0.8527,  0.6187, -1.2488,  0.3053,
#          1.4715,  0.2047,  0.3558,  0.2409,  0.8499,  0.2798])
# tensor([-0.1957,  0.3659, -1.8744, -1.4473,  1.0419, -0.7933, -0.3247,  0.1608,
#          1.4083,  2.0132,  0.2615,  1.1895, -0.7192, -0.8945, -0.1287,  0.6286,
#         -0.1858,  0.0897,  0.3478, -0.6387, -0.8527,  0.6187, -1.2488,  0.3053,
#          1.4715,  0.2047,  0.3558,  0.2409,  0.8499,  0.2798])
# ...
